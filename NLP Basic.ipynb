# %%
import nltk
#nltk.download()
text = """Welome to Yoon's NLP journey. Let's start with first turorial on NLTK! I shall learn the basics of NLTK hear."""
from nltk.tokenize import word_tokenize
print(word_tokenize(text))
# Out:
# ['Welome', 'to', 'Yoon', "'s", 'NLP', 'journey', '.', 'Let', "'s", 'start', 'with', 'first', 'turorial', 'on', 'NLTK', '!', 'I', 'shall', 'learn', 'the', 'basics', 'of', 'NLTK', 'hear', '.']

# %%
import nltk
print(nltk.data.path)
# Out:
# ['/home/yoon-myat-phoo/nltk_data', '/usr/nltk_data', '/usr/share/nltk_data', '/usr/lib/nltk_data', '/usr/share/nltk_data', '/usr/local/share/nltk_data', '/usr/lib/nltk_data', '/usr/local/lib/nltk_data']

# %%
# Turorial 1: Getting started With NLTK
import matplotlib.pyplot as plt
text = """ Install NLTK: run pip install --user -U nltk · Install Numpy (optional): run pip install --user -U numpy · Test installation: run python then type import nltk."""
from nltk.tokenize import word_tokenize
word_tokenized = word_tokenize(text)
from nltk.probability import FreqDist
fd = FreqDist(word_tokenized)
print (fd.most_common(3))
fd.plot(30,cumulative=False)
plt.show()
# Out:
# [(':', 3), ('run', 3), ('Install', 2)]

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /home/yoon-myat-
# [nltk_data]     phoo/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Tutorial 2: Removing stop words using NLTK 
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
#print(stop_words)
text ="""Welome to Yoon's NLP journey. Let's start with first turorial on NLTK! I shall learn the basics of NLTK hear."""

from nltk.tokenize import word_tokenize,sent_tokenize
tokenized_words = word_tokenize(text)
#print(words_tokenized)

tokenized_words_without_stop_words = []
for word in tokenized_words:
    if word not in stop_words:
        tokenized_words_without_stop_words.append(word)
print("stops_words which got removed",set(tokenized_words) - set(tokenized_words_without_stop_words))
print("tokenized_words which included all the words including stops_words",tokenized_words)
print("this is without stop_words",tokenized_words_without_stop_words)
# Out:
# stops_words which got removed {'to', 'on', 'the', 'with', 'of'}
# tokenized_words which included all the words including stops_words ['Welome', 'to', 'Yoon', "'s", 'NLP', 'journey', '.', 'Let', "'s", 'start', 'with', 'first', 'turorial', 'on', 'NLTK', '!', 'I', 'shall', 'learn', 'the', 'basics', 'of', 'NLTK', 'hear', '.']
# this is without stop_words ['Welome', 'Yoon', "'s", 'NLP', 'journey', '.', 'Let', "'s", 'start', 'first', 'turorial', 'NLTK', '!', 'I', 'shall', 'learn', 'basics', 'NLTK', 'hear', '.']

# %%
import nltk
nltk.download('wordnet')
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package wordnet to /home/yoon-myat-
# [nltk_data]     phoo/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to /home/yoon-myat-
# [nltk_data]     phoo/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
from nltk import PorterStemmer, WordNetLemmatizer
text = """Welome to Yoon's NLP journey. Let's start with first turorial on NLTK! I shall learn the basics of NLTK hear."""
demoWords = ["playing","happiness","going","doing","yes","no","I","having","had","haved","coding","programming","code"]
lemmatizer = WordNetLemmatizer()
stemmer = PorterStemmer()
for word in demoWords:
    # word stem lemmatize
    print(word,stemmer.stem(word),lemmatizer.lemmatize(word,"v"))
# Out:
# playing play play
# happiness happi happiness
# going go go
# doing do do
# yes ye yes
# no no no
# I i I
# having have have
# had had have
# haved have have
# coding code cod
# programming program program
# code code code

# %%
# Tutorial 3: Sentiment Analysis, Lemmatization and Stemming in NLTK
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.sentiment import SentimentIntensityAnalyzer

text = """Welome to Yoon's NLP journey. Let's start with first turorial on NLTK! I shall learn the basics of NLTK hear."""
demoWords = ["playing", "happiness", "going", "doing", "yes", "no", "I", "having", "had", "haved", "coding", "programming", "code"]

# Initialize SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()

# Analyze the sentiment of the sentence
print(sia.polarity_scores("Programming is fun"))
print(sia.polarity_scores("You behaved very bad today"))
# Out:
# {'neg': 0.0, 'neu': 0.377, 'pos': 0.623, 'compound': 0.5106}
# {'neg': 0.487, 'neu': 0.513, 'pos': 0.0, 'compound': -0.5849}

# %%
# Tutorial 4: Finding Meanings, Synonyms and Antonyms of words using NLTK
import nltk
from nltk.corpus import wordnet
#syn = wordnet.synsets('Parent')
#print(syn[0].definition())

#synonyms = []
#for syn in wordnet.synsets('Computer'):
#   for lemma in syn.lemmas():
#       synonyms.append(lemma.name())
#print(synonyms)

antonyms = []
for syn in wordnet.synsets('small'):
    for lemma in syn.lemmas():
        if lemma.antonyms():
            antonyms.append(lemma.antonyms()[0].name())
# Remove duplicates
antonyms = list(set(antonyms))
print(antonyms)
# Out:
# ['big', 'large']
